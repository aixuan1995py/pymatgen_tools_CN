# %%
import pymatgen.core as mg
from pymatgen.ext.matproj import MPRester

# %%
mpr = MPRester()
data = mpr.query(criteria={"elements": {"$all": ["Fe", "O"]}}, properties=["pretty_formula","material_id", "icsd_ids"])
data = mpr.query(criteria={"elements": {"$in": ["S","Se","Te"]}, "nelements": 2,'spacegroup.symbol': 'P6_3/mmc'}, 
               properties=["icsd_ids", "pretty_formula", "spacegroup","cif.conventional_standard","unit_cell_formula"])
# Out:
#   0%|          | 0/7681 [00:00<?, ?it/s]

# %%
data
# Out:
# [{'icsd_ids': [33613, 52211, 601915, 651358, 83867],
#   'pretty_formula': 'VS',
#   'spacegroup': {'symprec': 0.1,
#    'source': 'spglib',
#    'symbol': 'P6_3/mmc',
#    'number': 194,
#    'point_group': '6/mmm',
#    'crystal_system': 'hexagonal',
#    'hall': '-P 6c 2c'},
#   'cif.conventional_standard': None,
#   'unit_cell_formula': {'V': 2.0, 'S': 2.0}},
#  {'icsd_ids': [44870],
#   'pretty_formula': 'TeIr',
#   'spacegroup': {'symprec': 0.1,
#    'source': 'spglib',
#    'symbol': 'P6_3/mmc',
#    'number': 194,
#    'point_group': '6/mmm',
#    'crystal_system': 'hexagonal',
#    'hall': '-P 6c 2c'},
#   'cif.conventional_standard': None,
#   'unit_cell_formula': {'Te': 2.0, 'Ir': 2.0}},
#  {'icsd_ids': [84181, 651384, 651387, 202366, 56014],
#   'pretty_formula': 'WS2',
#   'spacegroup': {'symprec': 0.1,
#    'source': 'spglib',
#    'symbol': 'P6_3/mmc',
#    'number': 194,
#    'point_group': '6/mmm',
#    'crystal_system': 'hexagonal',
#    'hall': '-P 6c 2c'},
# ...
